# %%
from bs4 import BeautifulSoup
import requests

# %%
url= 'https://en.wikipedia.org/wiki/List_of_largest_shopping_malls_in_the_United_States'
page = requests.get(url)
soup = BeautifulSoup(page.text, 'html')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of largest shopping malls in the United States - Wikipedia</title>
# ...

# %%
<table class="wikitable sortable jquery-tablesorter">
<thead><tr>
# Out:
#   Cell In[12], line 1
#     <table class="wikitable sortable jquery-tablesorter">
#     ^
# SyntaxError: invalid syntax

# %%
soup.find('table', class_="wikitable sortable" )
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th data-sort-type="number">#</th>
# <th>Mall name</th>
# <th>Location</th>
# <th>Metro area</th>
# <th>Retail space<br/>Sq. feet/(m<sup>2</sup>)</th>
# <th>Stores</th>
# <th><a class="mw-redirect" href="/wiki/Anchor_store" title="Anchor store">Anchor stores</a>/entertainment venues</th>
# <th>Year opened</th>
# <th>Ownership
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><a href="/wiki/Mall_of_America" title="Mall of America">Mall of America</a>
# </td>
# <td><a href="/wiki/Bloomington,_Minnesota" title="Bloomington, Minnesota">Bloomington, Minnesota</a>
# </td>
# <td><a href="/wiki/Minneapolis%E2%80%93Saint_Paul" title="Minneapolis–Saint Paul">Minneapolis–Saint Paul</a>
# </td>
# <td>5,600,000 square feet (520,000 m<sup>2</sup>)<sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup>
# </td>
# <td>520
# </td>
# ...

# %%
soup.find_all('table')[1]
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th data-sort-type="number">#</th>
# <th>Mall name</th>
# <th>Location</th>
# <th>Metro area</th>
# <th>Retail space<br/>Sq. feet/(m<sup>2</sup>)</th>
# <th>Stores</th>
# <th><a class="mw-redirect" href="/wiki/Anchor_store" title="Anchor store">Anchor stores</a>/entertainment venues</th>
# <th>Year opened</th>
# <th>Ownership
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><a href="/wiki/Mall_of_America" title="Mall of America">Mall of America</a>
# </td>
# <td><a href="/wiki/Bloomington,_Minnesota" title="Bloomington, Minnesota">Bloomington, Minnesota</a>
# </td>
# <td><a href="/wiki/Minneapolis%E2%80%93Saint_Paul" title="Minneapolis–Saint Paul">Minneapolis–Saint Paul</a>
# </td>
# <td>5,600,000 square feet (520,000 m<sup>2</sup>)<sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup>
# </td>
# <td>520
# </td>
# ...

# %%
table = soup.find_all('table')[1]

# %%
print(table)
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th data-sort-type="number">#</th>
# <th>Mall name</th>
# <th>Location</th>
# <th>Metro area</th>
# <th>Retail space<br/>Sq. feet/(m<sup>2</sup>)</th>
# <th>Stores</th>
# <th><a class="mw-redirect" href="/wiki/Anchor_store" title="Anchor store">Anchor stores</a>/entertainment venues</th>
# <th>Year opened</th>
# <th>Ownership
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><a href="/wiki/Mall_of_America" title="Mall of America">Mall of America</a>
# </td>
# <td><a href="/wiki/Bloomington,_Minnesota" title="Bloomington, Minnesota">Bloomington, Minnesota</a>
# </td>
# <td><a href="/wiki/Minneapolis%E2%80%93Saint_Paul" title="Minneapolis–Saint Paul">Minneapolis–Saint Paul</a>
# </td>
# <td>5,600,000 square feet (520,000 m<sup>2</sup>)<sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup>
# </td>
# <td>520
# </td>
# ...

# %%
world_titles = table.find_all('th')

# %%
world_titles
# Out:
# [<th data-sort-type="number">#</th>,
#  <th>Mall name</th>,
#  <th>Location</th>,
#  <th>Metro area</th>,
#  <th>Retail space<br/>Sq. feet/(m<sup>2</sup>)</th>,
#  <th>Stores</th>,
#  <th><a class="mw-redirect" href="/wiki/Anchor_store" title="Anchor store">Anchor stores</a>/entertainment venues</th>,
#  <th>Year opened</th>,
#  <th>Ownership
#  </th>]

# %%
world_table_titles = [title.text.strip() for title in world_titles]

# %%
world_table_titles
# Out:
# ['#',
#  'Mall name',
#  'Location',
#  'Metro area',
#  'Retail spaceSq. feet/(m2)',
#  'Stores',
#  'Anchor stores/entertainment venues',
#  'Year opened',
#  'Ownership']

# %%
import pandas as pd

# %%
titles = pd.DataFrame(columns = world_table_titles)

# %%
titles
# Out:
# Empty DataFrame
# Columns: [#, Mall name, Location, Metro area, Retail spaceSq. feet/(m2), Stores, Anchor stores/entertainment venues, Year opened, Ownership]
# Index: []

# %%
column_data = table.find_all('tr')

# %%
for row in column_data[1:]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]
   
    length =len(titles)
    titles.loc[length] = individual_row_data

# %%
titles
# Out:
#      #                     Mall name                       Location  \
# 0    1               Mall of America         Bloomington, Minnesota
# 1    2                American Dream    East Rutherford, New Jersey
# 2    3                 Aventura Mall              Aventura, Florida
# 3    4             South Coast Plaza         Costa Mesa, California
# 4    5          King of Prussia Mall  King of Prussia, Pennsylvania
# ..  ..                           ...                            ...
# 75  16  Westfield Garden State Plaza            Paramus, New Jersey
# 76  17               Lakewood Center           Lakewood, California
# 77  18              Green Acres Mall        Valley Stream, New York
# 78  19               Oakbrook Center            Oak Brook, Illinois
# 79  20              NorthPark Center                  Dallas, Texas
#
#                                Metro area  \
# 0                  Minneapolis–Saint Paul
# 1                           New York City
# ...

# %%
titles.to_csv(r'C:\Users\user\OneDrive\Desktop\Datasets\Companies.csv', index= False)
